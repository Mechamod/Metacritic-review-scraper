# %% [markdown]
# # User-Agent Scraper
#
# A small scraper that creates a list of user-agent string for further using (especially for scraping, so we are not that likely to get blocked). The user-agent strings get scraped from https://udger.com/resources/ua-list. The program works on BeautifulSoup 4 and pandas for the dataframe. Workflow is like follows:
#
# 1. Get a list of available browsers and define a list of the ones we want to use.
# 2. Open each of these Browser user-agent sites.
# 3. Scrape all the available user-agents and save all the informaiton in a triple (name, url, user-agent).
# 4. Write them into a dataframe
#
# Optionally, implement a helper method that loads this file and outputs a dataframe containing user-agents. So that the UA can easy be used in other programs.

# %%
# Constants
UDGER_URL = "https://udger.com"
BROWSER_LIST_LINK = "https://udger.com/resources/ua-list"
BROWSER_NAMES = []
BROWSER_LINKS = []
TRIPLE = []

# %%
import requests
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm
import pandas as pd
tqdm().pandas()
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# /home/tim/anaconda3/lib/python3.7/site-packages/tqdm/std.py:668: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %% [markdown]
# Get a list of all the available browsers with their corresponing links as a tuple so it is easy to loop through it and pick only the ones we want (or all)

# %%
page = requests.get(BROWSER_LIST_LINK)
soup = BeautifulSoup(page.content, 'lxml')
table = soup.find_all("table")[0]
tds = table.find_all("td")
browser_tds = []
for td in tqdm(tds):
    if str(td).startswith("<td><a href=\"/resources/ua-list/browser-detail?browser=") & (len(browser_tds) < 200):
        browser_tds.append(td)
        
print(f"{len(browser_tds)} Browsers found")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2903.0), HTML(value='')))
# 200 Browsers found

# %%
# Loading browser names and their urls
for browser_td in tqdm(browser_tds):
    name = str(browser_td.get_text())
    url = UDGER_URL + str(browser_td.find()["href"]).replace(" ","%20")
    BROWSER_NAMES.append(name)
    BROWSER_LINKS.append(url)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))

# %%
# Get all available user-agents, create and add tuples with them, saving all the information
for i in tqdm(range(len(BROWSER_NAMES))):
    name = BROWSER_NAMES[i]
    url = BROWSER_LINKS[i]
    
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'lxml')
    ua_links = soup.find_all("a", href=True)
    for link in ua_links:
        if "/resources/online-parser" in str(link) and link.get_text() != "Online parser":
            ua = (link.get_text())
            information_set = (name, url, ua)
            print(information_set)
            TRIPLE.append(information_set)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# ('115 Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=115%20Browser', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.59 Safari/537.36 115Browser/8.6.2')
# ('2345 Explorer', 'https://udger.com/resources/ua-list/browser-detail?browser=2345%20Explorer', 'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 1.1.4322; 2345Explorer 5.0.0.14136)')
# ('2345 Explorer', 'https://udger.com/resources/ua-list/browser-detail?browser=2345%20Explorer', 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.108 Safari/537.36 2345Explorer/7.1.0.12633')
# ('360 browser', 'https://udger.com/resources/ua-list/browser-detail?browser=360%20browser', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/21.0.1180.89 Safari/537.1 QIHU 360SE')
# ('360 browser', 'https://udger.com/resources/ua-list/browser-detail?browser=360%20browser', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.17 (KHTML, like Gecko) Chrome/24.0.1312.57 Safari/537.17 QIHU 360EE')
# ('360 browser', 'https://udger.com/resources/ua-list/browser-detail?browser=360%20browser', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.152 Safari/537.36 QIHU 360SE')
# ('360 browser', 'https://udger.com/resources/ua-list/browser-detail?browser=360%20browser', 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; Trident/5.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; 360SE)')
# ('37abc', 'https://udger.com/resources/ua-list/browser-detail?browser=37abc', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) 37abc/2.0.6.16 Chrome/60.0.3112.113 Safari/537.36')
# ('37abc', 'https://udger.com/resources/ua-list/browser-detail?browser=37abc', 'Mozilla/5.0 (Windows NT 6.0) AppleWebKit/537.36 (KHTML like Gecko) 37abc/1.6.3.9 Chrome/44.0.2403.130 Safari/537.36')
# ('3DS Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=3DS%20Browser', 'Mozilla/5.0 (Nintendo 3DS; U; ; en) Version/1.7552.EU')
# ('7 Star Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=7%20Star%20Browser', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.152 Kuaiso/1.42.501.445 Safari/537.36')
# ('Abolimba', 'https://udger.com/resources/ua-list/browser-detail?browser=Abolimba', 'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; JyxoToolbar1.0; http://www.Abolimba.de; .NET CLR 2.0.50727; .NET CLR 3.0.04506.648; .NET CLR 3.5.21022; .NET CLR 1.1.4322)')
# ('Abolimba', 'https://udger.com/resources/ua-list/browser-detail?browser=Abolimba', 'Mozilla/4.0 (compatible; MSIE 6.0; Windows 98; Win 9x 4.90; http://www.Abolimba.de)')
# ('ABrowse', 'https://udger.com/resources/ua-list/browser-detail?browser=ABrowse', 'Mozilla/5.0 (compatible; U; ABrowse 0.6; Syllable) AppleWebKit/420+ (KHTML, like Gecko)')
# ('ABrowse', 'https://udger.com/resources/ua-list/browser-detail?browser=ABrowse', 'Mozilla/5.0 (compatible; ABrowse 0.4; Syllable)')
# ('ABrowse', 'https://udger.com/resources/ua-list/browser-detail?browser=ABrowse', 'Mozilla/5.0 (compatible; U; ABrowse 0.7; Syllable) AppleWebKit/420+ (KHTML, like Gecko)')
# ('Acoo Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Acoo%20Browser', 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0; Acoo Browser; SLCC1; .NET CLR 2.0.50727; Media Center PC 5.0; .NET CLR 3.0.04506)')
# ('Acoo Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Acoo%20Browser', 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; Acoo Browser; InfoPath.2; .NET CLR 2.0.50727; Alexa Toolbar)')
# ('Acoo Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Acoo%20Browser', 'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; Acoo Browser; .NET CLR 1.1.4322; .NET CLR 2.0.50727)')
# ('Adventurer', 'https://udger.com/resources/ua-list/browser-detail?browser=Adventurer', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1500.95 Adventurer/2.0.1.19 Safari/537.36')
# ('Adventurer', 'https://udger.com/resources/ua-list/browser-detail?browser=Adventurer', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.85 Adventurer/3.1.0.7 Safari/537.36')
# ('Alienforce', 'https://udger.com/resources/ua-list/browser-detail?browser=Alienforce', 'Mozilla/5.0 (Windows NT 6.1; rv:8.0) Gecko/20111108 Firefox/8.0 Alienforce/8.0')
# ('Alienforce', 'https://udger.com/resources/ua-list/browser-detail?browser=Alienforce', 'Mozilla/5.0 (Windows NT 6.1; rv:9.0.1) Gecko/20100101 Firefox/9.0.1 Alienforce3.0/9.0.1')
# ('Amaya', 'https://udger.com/resources/ua-list/browser-detail?browser=Amaya', 'amaya/9.52 libwww/5.4.0')
# ('Amaya', 'https://udger.com/resources/ua-list/browser-detail?browser=Amaya', 'amaya/11.1 libwww/5.4.0')
# ('Amiga Aweb', 'https://udger.com/resources/ua-list/browser-detail?browser=Amiga%20Aweb', 'Amiga-AWeb/3.5.07 beta')
# ('Amiga Voyager', 'https://udger.com/resources/ua-list/browser-detail?browser=Amiga%20Voyager', 'AmigaVoyager/3.4.4 (MorphOS/PPC native)')
# ('Amiga Voyager', 'https://udger.com/resources/ua-list/browser-detail?browser=Amiga%20Voyager', 'AmigaVoyager/2.95 (compatible; MC680x0; AmigaOS)')
# ('Amiga Voyager', 'https://udger.com/resources/ua-list/browser-detail?browser=Amiga%20Voyager', 'AmigaVoyager/3.2 (AmigaOS/MC680x0)')
# ('Amigo', 'https://udger.com/resources/ua-list/browser-detail?browser=Amigo', 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.47 Safari/535.11 MRCHROME')
# ('Amigo', 'https://udger.com/resources/ua-list/browser-detail?browser=Amigo', 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.1.963.51 Safari/535.11 MRCHROME SOC')
# ('Amigo', 'https://udger.com/resources/ua-list/browser-detail?browser=Amigo', 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1501.78 Safari/537.36 MRCHROME SOC')
# ('Amigo', 'https://udger.com/resources/ua-list/browser-detail?browser=Amigo', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.191 Amigo/54.0.2840.191 MRCHROME SOC Safari/537.36')
# ('ANT Fresco', 'https://udger.com/resources/ua-list/browser-detail?browser=ANT%20Fresco', 'Mozilla/3.04 (compatible; ANTFresco/2.13; RISC OS 4.02)')
# ('ANT Fresco', 'https://udger.com/resources/ua-list/browser-detail?browser=ANT%20Fresco', 'Mozilla/3.04 (compatible; NCBrowser/2.35; ANTFresco/2.17; RISC OS-NC 5.13 Laz1UK1309)')
# ('ANT Galio', 'https://udger.com/resources/ua-list/browser-detail?browser=ANT%20Galio', 'HbbTV/1.1.1 (;Hisense;MT5651;;;) ANTGalio/3.3.0.26.04')
# ('AOL Desktop', 'https://udger.com/resources/ua-list/browser-detail?browser=AOL%20Desktop', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 ADG/11.0.2131 Safari/537.36')
# ('AOL Explorer', 'https://udger.com/resources/ua-list/browser-detail?browser=AOL%20Explorer', 'Mozilla/4.0 (compatible; MSIE 6.0; AOL 6.0; Windows NT 5.1)')
# ('AOL Explorer', 'https://udger.com/resources/ua-list/browser-detail?browser=AOL%20Explorer', 'Mozilla/4.0 (compatible; MSIE 7.0; AOL 7.0; Windows NT 5.1; FunWebProducts)')
# ('AOL Explorer', 'https://udger.com/resources/ua-list/browser-detail?browser=AOL%20Explorer', 'Mozilla/4.0 (compatible; MSIE 7.0; AOL 9.0; Windows NT 5.1; .NET CLR 1.1.4322; Zango 10.1.181.0)')
# ('AOL Explorer', 'https://udger.com/resources/ua-list/browser-detail?browser=AOL%20Explorer', 'Mozilla/4.0 (compatible; MSIE 7.0; AOL 9.5; AOLBuild 4337.35; Windows NT 5.1; .NET CLR 1.1.4322; .NET CLR 2.0.50727)')
# ('AOL Explorer', 'https://udger.com/resources/ua-list/browser-detail?browser=AOL%20Explorer', 'Mozilla/4.0 (compatible; MSIE 6.0; AOL 8.0; Windows NT 5.1; SV1)')
# ('AOL Explorer', 'https://udger.com/resources/ua-list/browser-detail?browser=AOL%20Explorer', 'Mozilla/4.0 (compatible; MSIE 8.0; AOL 9.6; AOLBuild 4340.17; Windows NT 5.1; Trident/4.0; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729)')
# ('AOL Explorer', 'https://udger.com/resources/ua-list/browser-detail?browser=AOL%20Explorer', 'Mozilla/4.0 (compatible; MSIE 7.0; AOL 9.1; AOLBuild 4334.5000; Windows NT 5.1; Media Center PC 3.0; .NET CLR 1.0.3705; .NET CLR 1.1.4322; InfoPath.1)')
# ('AOL Explorer', 'https://udger.com/resources/ua-list/browser-detail?browser=AOL%20Explorer', 'Mozilla/4.0 (compatible; MSIE 8.0; AOL 9.6; AOLBuild 4340.12; Windows NT 6.1; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0)')
# ('AOL Explorer', 'https://udger.com/resources/ua-list/browser-detail?browser=AOL%20Explorer', 'Mozilla/5.0 (AOL 9.7; AOLBuild 4343.55; Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.10240')
# ('AOL Explorer', 'https://udger.com/resources/ua-list/browser-detail?browser=AOL%20Explorer', 'Mozilla/5.0 (Windows NT 6.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.104 AOL/9.8 AOLBuild/4346.18.US Safari/537.36')
# ('AOL Shield', 'https://udger.com/resources/ua-list/browser-detail?browser=AOL%20Shield', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2841.00 Safari/537.36 AOLShield/54.0.2848.0')
# ('AOL Shield', 'https://udger.com/resources/ua-list/browser-detail?browser=AOL%20Shield', 'Mozilla/5.0 (Windows NT 6.1; rv:52.0) Gecko/20100101 AOLShield/52.4.2')
# ('Aplix', 'https://udger.com/resources/ua-list/browser-detail?browser=Aplix', 'Aplix_SEGASATURN_browser/1.x (Japanese)')
# ('Arachne', 'https://udger.com/resources/ua-list/browser-detail?browser=Arachne', 'xChaos_Arachne/5.1.89;GPL,386+')
# ('Arctic Fox', 'https://udger.com/resources/ua-list/browser-detail?browser=Arctic%20Fox', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.6; rv:52.9) Gecko/20100101 Goanna/3.4 Firefox/52.9 ArcticFox/27.9.15')
# ('Arora', 'https://udger.com/resources/ua-list/browser-detail?browser=Arora', 'Mozilla/5.0 (X11; U; Linux; C -) AppleWebKit/523.15 (KHTML, like Gecko, Safari/419.3) Arora/0.5')
# ('Arora', 'https://udger.com/resources/ua-list/browser-detail?browser=Arora', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; zh-CN) AppleWebKit/523.15 (KHTML, like Gecko, Safari/419.3) Arora/0.3 (Change: 287 c9dfb30)')
# ('Arora', 'https://udger.com/resources/ua-list/browser-detail?browser=Arora', 'Mozilla/5.0 (X11; U; Linux; en-US) AppleWebKit/527+ (KHTML, like Gecko, Safari/419.3) Arora/0.6')
# ('Arora', 'https://udger.com/resources/ua-list/browser-detail?browser=Arora', 'Mozilla/5.0 (X11; U; Linux; de-DE) AppleWebKit/527+ (KHTML, like Gecko, Safari/419.3) Arora/0.8.0')
# ('Atom', 'https://udger.com/resources/ua-list/browser-detail?browser=Atom', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.90 Atom/4.0.0.141 Safari/537.36')
# ('Avant Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Avant%20Browser', 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; GTB5; Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1) ; Avant Browser)')
# ('Avant Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Avant%20Browser', 'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; Avant Browser; Avant Browser; .NET CLR 1.1.4322; .NET CLR 2.0.50727; InfoPath.1)')
# ('Avant Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Avant%20Browser', 'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; JyxoToolbar1.0;  Embedded Web Browser from: http://bsalsa.com/; Avant Browser; .NET CLR 2.0.50727; .NET CLR 3.0.04506.648; .NET CLR 3.5.21022; .NET CLR 1.1.4322)')
# ('Avant Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Avant%20Browser', 'Avant Browser (http://www.avantbrowser.com)')
# ('Avant Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Avant%20Browser', 'Mozilla/5.0 (Windows NT 6.1; rv:12.0) Gecko/20120515 Firefox/12.0 AvantBrowser/Tri-Core')
# ('Avant Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Avant%20Browser', 'Mozilla/5.0 (Windows NT 6.1; rv:11.0) Gecko/20120325 Firefox/11.0 AvantBrowser/Tri-Core')
# ('Avant Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Avant%20Browser', 'Mozilla/5.0 (Windows NT 5.1; rv:11.0) Gecko/20120325 Firefox/11.0 AvantBrowser/Tri-Core')
# ('Avant Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Avant%20Browser', 'Mozilla/5.0 (Windows NT 6.2; WOW64; Trident/7.0; Avant Browser; rv:11.0) like Gecko')
# ('Avant Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Avant%20Browser', 'Mozilla/5.0 (Windows NT 6.3; WOW64; Avant TriCore) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/34.0.1847.131 Safari/537.36')
# ('Avant Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Avant%20Browser', 'Mozilla/5.0 (Windows NT 6.3; WOW64; rv:27.0; Avant TriCore) Gecko/20100101 Firefox/27.0')
# ('Avast Secure Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Avast%20Secure%20Browser', 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.106 Safari/537.36 ASW/1.51.2220.53')
# ('Avast Secure Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Avast%20Secure%20Browser', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.86 Safari/537.36 ASW/1.46.1990.139')
# ('Avast Secure Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Avast%20Secure%20Browser', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36 Avast/64.0.388.186')
# ('AVG Secure Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=AVG%20Secure%20Browser', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36 AVG/70.1.682.112')
# ('Aviator', 'https://udger.com/resources/ua-list/browser-detail?browser=Aviator', 'Mozilla/5.0 (Windows NT 6.0) AppleWebKit/537.36 (KHTML, like Gecko) WhiteHat Aviator/33.0.1750.117 Chrome/33.0.1750.117 Safari/537.36')
# ('Aviator', 'https://udger.com/resources/ua-list/browser-detail?browser=Aviator', 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) WhiteHat Aviator/33.0.1750.117 Chrome/33.0.1750.117 Safari/537.36')
# ('Avira Scout', 'https://udger.com/resources/ua-list/browser-detail?browser=Avira%20Scout', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36 AviraScout/16.11.2883.2017')
# ('Baidu Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Baidu%20Browser', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; zh_CN) AppleWebKit/534.7 (KHTML, like Gecko) Chrome/7.0 baidubrowser/1.x Safari/534.7')
# ('Baidu Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Baidu%20Browser', 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E; baidubrowser 1.x)')
# ('Baidu Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Baidu%20Browser', 'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; baidubrowser 1.x)')
# ('Baidu Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Baidu%20Browser', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; zh_CN) AppleWebKit/534.7 (KHTML, like Gecko) Chrome/7.0 baidubrowser/1.x Safari/534.7')
# ('Baidu Spark', 'https://udger.com/resources/ua-list/browser-detail?browser=Baidu%20Spark', 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.31 (KHTML, like Gecko) Chrome/26.0.1410.43 Spark/2.x Safari/537.31')
# ('Baidu Spark', 'https://udger.com/resources/ua-list/browser-detail?browser=Baidu%20Spark', 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.31 (KHTML, like Gecko) Chrome/26.0.1410.43 Spark/2.x Safari/537.31')
# ('Basilisk', 'https://udger.com/resources/ua-list/browser-detail?browser=Basilisk', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:55.0) Gecko/20100101 Goanna/4.0 Firefox/55.0 Basilisk/20171112')
# ('Beaker', 'https://udger.com/resources/ua-list/browser-detail?browser=Beaker', 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) BeakerBrowser/0.8.2 Chrome/66.0.3359.181 Electron/3.0.9 Safari/537.36')
# ('Beamrise', 'https://udger.com/resources/ua-list/browser-detail?browser=Beamrise', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/534.13 (KHTML, like Gecko) Chrome/9.0.597.98 Beamrise/4.20.13.22 Safari/534.13')
# ('Beamrise', 'https://udger.com/resources/ua-list/browser-detail?browser=Beamrise', 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.8 (KHTML like Gecko) Beamrise/17.2.0.5 Chrome/17.0.939.0 Safari/535.8')
# ('Beamrise', 'https://udger.com/resources/ua-list/browser-detail?browser=Beamrise', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.8 (KHTML, like Gecko) Beamrise/17.2.0.9 Chrome/17.0.939.0 Safari/535.8')
# ('Beamrise', 'https://udger.com/resources/ua-list/browser-detail?browser=Beamrise', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Beamrise/27.3.0.5964 Chrome/27.0.1453.116 Safari/537.36')
# ('Beonex', 'https://udger.com/resources/ua-list/browser-detail?browser=Beonex', 'Mozilla/5.0 (Windows; U; WinNT; en; rv:1.0.2) Gecko/20030311 Beonex/0.8.2-stable')
# ('Beonex', 'https://udger.com/resources/ua-list/browser-detail?browser=Beonex', 'Mozilla/5.0 (Windows; U; Win9x; en; Stable) Gecko/20020911 Beonex/0.8.1-stable')
# ('Beonex', 'https://udger.com/resources/ua-list/browser-detail?browser=Beonex', 'Mozilla/5.0 (Windows; U; WinNT; en; Preview) Gecko/20020603 Beonex/0.8-stable')
# ('Blackbird', 'https://udger.com/resources/ua-list/browser-detail?browser=Blackbird', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9) Gecko/2008120120 Blackbird/0.9991')
# ('BlackHawk', 'https://udger.com/resources/ua-list/browser-detail?browser=BlackHawk', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US) AppleWebKit/534.3 (KHTML, like Gecko) BlackHawk/1.0.195.0 Chrome/127.0.0.1 Safari/62439616.534')
# ('BlackHawk', 'https://udger.com/resources/ua-list/browser-detail?browser=BlackHawk', 'Mozilla/5.0 (Windows NT 6.1; rv:25.3) Gecko/20150425 BlackHawk/25.3.1')
# ('Bolt', 'https://udger.com/resources/ua-list/browser-detail?browser=Bolt', 'Mozilla/5.0 (X11; 78; CentOS; US-en) AppleWebKit/527+ (KHTML, like Gecko) Bolt/0.862 Version/3.0 Safari/523.15')
# ('Bolt', 'https://udger.com/resources/ua-list/browser-detail?browser=Bolt', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; BOLT/2.514) AppleWebKit/534.6 (KHTML, like Gecko) Version/5.0 Safari/534.6.3')
# ('Brave', 'https://udger.com/resources/ua-list/browser-detail?browser=Brave', 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) brave/0.7.10 Chrome/47.0.2526.110 Brave/0.36.5 Safari/537.36')
# ('Brave', 'https://udger.com/resources/ua-list/browser-detail?browser=Brave', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/537.36 (KHTML, like Gecko) brave/0.7.11 Chrome/47.0.2526.110 Brave/0.36.5 Safari/537.36')
# ('BriskBard', 'https://udger.com/resources/ua-list/browser-detail?browser=BriskBard', 'BriskBard/1.0 (Windows 6.1) BriskBard/1.0')
# ('BriskBard', 'https://udger.com/resources/ua-list/browser-detail?browser=BriskBard', 'BriskBard/1.0 (Windows 10) BriskBard/1.0')
# ('BrowseX', 'https://udger.com/resources/ua-list/browser-detail?browser=BrowseX', 'Mozilla/4.61 [en] (X11; U; ) - BrowseX (2.0.0 Windows)')
# ('Browzar', 'https://udger.com/resources/ua-list/browser-detail?browser=Browzar', 'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; Browzar)')
# ('Bunjalloo', 'https://udger.com/resources/ua-list/browser-detail?browser=Bunjalloo', 'Bunjalloo/0.7.6(Nintendo DS;U;en)')
# ('Bunjalloo', 'https://udger.com/resources/ua-list/browser-detail?browser=Bunjalloo', 'Bunjalloo/0.7.4(Nintendo DS;U;en)')
# ('Camino', 'https://udger.com/resources/ua-list/browser-detail?browser=Camino', 'Mozilla/5.0 (Macintosh; U; PPC Mac OS X Mach-O; en; rv:1.8.1.4pre) Gecko/20070511 Camino/1.6pre')
# ('Camino', 'https://udger.com/resources/ua-list/browser-detail?browser=Camino', 'Mozilla/5.0 (Macintosh; U; Intel Mac OS X Mach-O; en; rv:1.8.1.12) Gecko/20080206 Camino/1.5.5')
# ('Camino', 'https://udger.com/resources/ua-list/browser-detail?browser=Camino', 'Mozilla/5.0 (Macintosh; U; PPC Mac OS X Mach-O; en-US; rv:1.8.0.10) Gecko/20070228 Camino/1.0.4')
# ('Camino', 'https://udger.com/resources/ua-list/browser-detail?browser=Camino', 'Mozilla/5.0 (Macintosh; U; PPC Mac OS X Mach-O; en-US; rv:1.7.2) Gecko/20040825 Camino/0.8.1')
# ('Camino', 'https://udger.com/resources/ua-list/browser-detail?browser=Camino', 'Mozilla/5.0 (Macintosh; U; PPC Mac OS X Mach-O; en-US; rv:1.0.1) Gecko/20030111 Chimera/0.6')
# ('Camino', 'https://udger.com/resources/ua-list/browser-detail?browser=Camino', 'Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10.5; en; rv:1.9.2.28) Gecko/20120308 Camino/2.1.2 (like Firefox/3.6.28)')
# ('Camino', 'https://udger.com/resources/ua-list/browser-detail?browser=Camino', 'Mozilla/5.0 (Macintosh; PPC Mac OS X 10.5; rv:2.0.1) Gecko/20100101 Firefox/4.0.1 Camino/2.2.1')
# ('CCleaner Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=CCleaner%20Browser', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36 CCleaner/75.1.103.145')
# ('Charon', 'https://udger.com/resources/ua-list/browser-detail?browser=Charon', 'Mozilla/4.08 (Charon; Inferno)')
# ('Chedot', 'https://udger.com/resources/ua-list/browser-detail?browser=Chedot', 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chedot/43.0.2357.402 Safari/537.36')
# ('Chedot', 'https://udger.com/resources/ua-list/browser-detail?browser=Chedot', 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.78 Chedot/8.0.0 Safari/537.36')
# ('Cheshire', 'https://udger.com/resources/ua-list/browser-detail?browser=Cheshire', 'Mozilla/5.0 (Macintosh; U; PPC Mac OS X; en) AppleWebKit/419 (KHTML, like Gecko, Safari/419.3) Cheshire/1.0.ALPHA')
# ('Cheshire', 'https://udger.com/resources/ua-list/browser-detail?browser=Cheshire', 'Mozilla/5.0 (Macintosh; U; PPC Mac OS X; en) AppleWebKit/418.9 (KHTML, like Gecko, Safari) Safari/419.3 Cheshire/1.0.ALPHA')
# ('Chim Lac', 'https://udger.com/resources/ua-list/browser-detail?browser=Chim%20Lac', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) chimlac_browser/1.0 Chrome/57.0.2987.110 Safari/537.36')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/525.19 (KHTML, like Gecko) Chrome/1.0.154.53 Safari/525.19')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/525.19 (KHTML, like Gecko) Chrome/1.0.154.36 Safari/525.19')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US) AppleWebKit/534.10 (KHTML, like Gecko) Chrome/7.0.540.0 Safari/534.10')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows; U; Windows NT 5.2; en-US) AppleWebKit/534.4 (KHTML, like Gecko) Chrome/6.0.481.0 Safari/534.4')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Macintosh; U; Intel Mac OS X; en-US) AppleWebKit/533.4 (KHTML, like Gecko) Chrome/5.0.375.86 Safari/533.4')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/532.2 (KHTML, like Gecko) Chrome/4.0.223.3 Safari/532.2')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US) AppleWebKit/532.0 (KHTML, like Gecko) Chrome/4.0.201.1 Safari/532.0')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows; U; Windows NT 5.2; en-US) AppleWebKit/532.0 (KHTML, like Gecko) Chrome/3.0.195.27 Safari/532.0')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/530.5 (KHTML, like Gecko) Chrome/2.0.173.1 Safari/530.5')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows; U; Windows NT 5.2; en-US) AppleWebKit/534.10 (KHTML, like Gecko) Chrome/8.0.558.0 Safari/534.10')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (X11; U; Linux x86_64; en-US) AppleWebKit/540.0 (KHTML,like Gecko) Chrome/9.1.0.0 Safari/540.0')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/534.14 (KHTML, like Gecko) Chrome/9.0.600.0 Safari/534.14')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (X11; U; Windows NT 6; en-US) AppleWebKit/534.12 (KHTML, like Gecko) Chrome/9.0.587.0 Safari/534.12')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US)  AppleWebKit/534.13 (KHTML, like Gecko) Chrome/9.0.597.0 Safari/534.13')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US) AppleWebKit/534.16 (KHTML, like Gecko) Chrome/10.0.648.11 Safari/534.16')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows; U; Windows NT 6.0; en-US) AppleWebKit/534.20 (KHTML, like Gecko) Chrome/11.0.672.2 Safari/534.20')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows NT 6.0) AppleWebKit/535.1 (KHTML, like Gecko) Chrome/14.0.792.0 Safari/535.1')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.2 (KHTML, like Gecko) Chrome/15.0.872.0 Safari/535.2')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.7 (KHTML, like Gecko) Chrome/16.0.912.36 Safari/535.7')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows NT 6.0; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.66 Safari/535.11')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8) AppleWebKit/535.19 (KHTML, like Gecko) Chrome/18.0.1025.45 Safari/535.19')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.15 (KHTML, like Gecko) Chrome/24.0.1295.0 Safari/537.15')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.93 Safari/537.36')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1467.0 Safari/537.36')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/30.0.1599.101 Safari/537.36')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1623.0 Safari/537.36')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/34.0.1847.116 Safari/537.36')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/40.0.2214.38 Safari/537.36')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.71 Safari/537.36')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.62 Safari/537.36')
# ('Chrome', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome', 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36')
# ('Chrome frozen UA', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome%20frozen%20UA', 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3764.0 Safari/537.36')
# ('Chrome Headless', 'https://udger.com/resources/ua-list/browser-detail?browser=Chrome%20Headless', 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome Safari/537.36')
# ('Chromium', 'https://udger.com/resources/ua-list/browser-detail?browser=Chromium', 'Mozilla/5.0 (X11; U; Linux x86_64; en-US) AppleWebKit/534.10 (KHTML, like Gecko) Ubuntu/10.10 Chromium/8.0.552.237 Chrome/8.0.552.237 Safari/534.10')
# ('Chromium', 'https://udger.com/resources/ua-list/browser-detail?browser=Chromium', 'Mozilla/5.0 (X11; Linux i686) AppleWebKit/535.7 (KHTML, like Gecko) Ubuntu/11.10 Chromium/16.0.912.21 Chrome/16.0.912.21 Safari/535.7')
# ('Chromium', 'https://udger.com/resources/ua-list/browser-detail?browser=Chromium', 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.2 (KHTML, like Gecko) Ubuntu/11.04 Chromium/15.0.871.0 Chrome/15.0.871.0 Safari/535.2')
# ('Chromium', 'https://udger.com/resources/ua-list/browser-detail?browser=Chromium', 'Mozilla/5.0 (X11; Linux i686) AppleWebKit/535.1 (KHTML, like Gecko) Ubuntu/10.04 Chromium/14.0.813.0 Chrome/14.0.813.0 Safari/535.1')
# ('Chromium', 'https://udger.com/resources/ua-list/browser-detail?browser=Chromium', 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/534.30 (KHTML, like Gecko) Ubuntu/10.10 Chromium/12.0.742.112 Chrome/12.0.742.112 Safari/534.30')
# ('Chromium', 'https://udger.com/resources/ua-list/browser-detail?browser=Chromium', 'Mozilla/5.0 (X11; U; Linux x86_64; en-US) AppleWebKit/534.10 (KHTML, like Gecko) Ubuntu/10.10 Chromium/8.0.552.237 Chrome/8.0.552.237 Safari/534.10')
# ('Chromium', 'https://udger.com/resources/ua-list/browser-detail?browser=Chromium', 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/34.0.1847.116 Chrome/34.0.1847.116 Safari/537.36')
# ('Chromodo', 'https://udger.com/resources/ua-list/browser-detail?browser=Chromodo', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Dragon/42.1.2.91 Chrome/42.0.2311.135 Safari/537.36')
# ('Chromodo', 'https://udger.com/resources/ua-list/browser-detail?browser=Chromodo', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Dragon/45.6.11.383 Chrome/45.0.2454.93 Safari/537.36')
# ('Classilla', 'https://udger.com/resources/ua-list/browser-detail?browser=Classilla', 'Mozilla/5.0 (Macintosh; U; PPC; en-US; mimic; rv:9.3.0) Clecko/20120101 Classilla/CFM')
# ('CM Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=CM%20Browser', 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/49.0.2623.75 Safari/537.36 LBBROWSER')
# ('Coc Coc', 'https://udger.com/resources/ua-list/browser-detail?browser=Coc%20Coc', 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/30.0.1599.105 CoRom/30.0.1599.105 Safari/537.36')
# ('Coc Coc', 'https://udger.com/resources/ua-list/browser-detail?browser=Coc%20Coc', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) coc_coc_browser/45.0 Chrome/39.0.2171.98 Safari/537.36')
# ('Coc Coc', 'https://udger.com/resources/ua-list/browser-detail?browser=Coc%20Coc', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) coc_coc_browser/45.0 Chrome/39.0.2171.98 Safari/537.36')
# ('Coc Coc', 'https://udger.com/resources/ua-list/browser-detail?browser=Coc%20Coc', 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) coc_coc_browser/44.0 CoRom/38.0.2125.102 Chrome/38.0')
# ('Coc Coc', 'https://udger.com/resources/ua-list/browser-detail?browser=Coc%20Coc', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/33.0.1750.157 CoRom/33.0.1750.157 CocCoc/33.0.1750.157 Safari/537.36')
# ('Colibri', 'https://udger.com/resources/ua-list/browser-detail?browser=Colibri', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Colibri/1.5.1 Chrome/61.0.3163.100 Electron/2.0.2 Safari/537.36')
# ('Columbus', 'https://udger.com/resources/ua-list/browser-detail?browser=Columbus', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; cs-CZ) AppleWebKit/533.3 (KHTML, like Gecko) Columbus/1.2.1.0 Safari/533.3')
# ('CometBird', 'https://udger.com/resources/ua-list/browser-detail?browser=CometBird', 'Mozilla/5.0 (Windows; U; Windows NT 6.0; en-US; rv:1.9.0.5) Gecko/2009011615 Firefox/3.0.5 CometBird/3.0.5')
# ('CometBird', 'https://udger.com/resources/ua-list/browser-detail?browser=CometBird', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.10) Gecko/2009042815 Firefox/3.0.10 CometBird/3.0.10')
# ('Comodo Dragon', 'https://udger.com/resources/ua-list/browser-detail?browser=Comodo%20Dragon', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/532.0 (KHTML, like Gecko) Comodo_Dragon/1.0.0.9 Chrome/ Version/3.2.1 Safari/532.0')
# ('Comodo Dragon', 'https://udger.com/resources/ua-list/browser-detail?browser=Comodo%20Dragon', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US) AppleWebKit/532.0 (KHTML, like Gecko) Comodo_Dragon/1.0.0.9 Chrome/ Version/3.2.1 Safari/532.0')
# ('Comodo Dragon', 'https://udger.com/resources/ua-list/browser-detail?browser=Comodo%20Dragon', 'Mozilla/5.0 (Windows; U; Windows NT 5.2; en-US) AppleWebKit/532.0 (KHTML, like Gecko) Comodo_Dragon/1.0.0.5 Safari/532.0')
# ('Comodo Dragon', 'https://udger.com/resources/ua-list/browser-detail?browser=Comodo%20Dragon', 'Mozilla/5.0 (Windows; U; Windows NT 6.0; en-US) AppleWebKit/534.10 (KHTML, like Gecko) Comodo_Dragon/8.0.0.4 Chrome/8.0.552.215 Safari/534.10')
# ('Comodo Dragon', 'https://udger.com/resources/ua-list/browser-detail?browser=Comodo%20Dragon', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/534.16 (KHTML, like Gecko) Comodo_Dragon/10.0.0.2 Chrome/10.0.648.204 Safari/534.16')
# ('Comodo Dragon', 'https://udger.com/resources/ua-list/browser-detail?browser=Comodo%20Dragon', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.1 (KHTML, like Gecko) Comodo_Dragon/14.0.1.0 Chrome/14.0.835.163 Safari/535.1')
# ('Conkeror', 'https://udger.com/resources/ua-list/browser-detail?browser=Conkeror', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.2.10) Gecko/20100914 Conkeror/0.9.3')
# ('Conkeror', 'https://udger.com/resources/ua-list/browser-detail?browser=Conkeror', 'Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.1.11) Gecko/20100721 Conkeror/0.9.2 (Debian-0.9.2+git100804-1)')
# ('Conkeror', 'https://udger.com/resources/ua-list/browser-detail?browser=Conkeror', 'Mozilla/5.0 (X11; Linux x86_64; rv:6.0.2) Gecko/20110916 conkeror/1.0pre')
# ('CoolNovo', 'https://udger.com/resources/ua-list/browser-detail?browser=CoolNovo', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.7 (KHTML, like Gecko) Chrome/16.0.912.63 Safari/535.7 CoolNovo/2.0.0.4')
# ('CoolNovo', 'https://udger.com/resources/ua-list/browser-detail?browser=CoolNovo', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.7 (KHTML, like Gecko) Chrome/16.0.912.63 Safari/535.7 CoolNovo/1.6.5.28')
# ('CoolNovo', 'https://udger.com/resources/ua-list/browser-detail?browser=CoolNovo', 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.7 (KHTML, like Gecko) Chrome/16.0.912.63 Safari/535.7 CoolNovo/2.0.0.4')
# ('CoolNovo', 'https://udger.com/resources/ua-list/browser-detail?browser=CoolNovo', 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.110 Safari/537.36 CoolNovo/2.0.9.20')
# ('Crazy Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Crazy%20Browser', 'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; Crazy Browser 1.0.5; .NET CLR 1.1.4322; InfoPath.1)')
# ('Crazy Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Crazy%20Browser', 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; .NET CLR 1.1.4322; .NET CLR 2.0.50727; Crazy Browser 3.0.0 Beta2)')
# ('Crazy Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Crazy%20Browser', 'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; .NET CLR 1.1.4322; Crazy Browser 2.0.1)')
# ('Crazy Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Crazy%20Browser', 'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; Crazy Browser 1.0.5)')
# ('Cuam', 'https://udger.com/resources/ua-list/browser-detail?browser=Cuam', 'Cuam Ver0.050bx  ')
# ('Cunaguaro', 'https://udger.com/resources/ua-list/browser-detail?browser=Cunaguaro', 'Mozilla/5.0 (X11; Linux i686; rv:8.0) Gecko/20100101 Firefox/8.0 Cunaguaro/8.0')
# ('Cunaguaro', 'https://udger.com/resources/ua-list/browser-detail?browser=Cunaguaro', 'Mozilla/5.0 (X11; Linux i686; rv:27.0) Gecko/20100101 Firefox/27.0 Cunaguaro/27.0')
# ('Cyberdog', 'https://udger.com/resources/ua-list/browser-detail?browser=Cyberdog', 'Cyberdog/2.0 (Macintosh; PPC)')
# ('Cyberfox', 'https://udger.com/resources/ua-list/browser-detail?browser=Cyberfox', 'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:28.0) Gecko/20100101 Firefox/28.0 Cyberfox/28.0.1')
# ('Cyberfox', 'https://udger.com/resources/ua-list/browser-detail?browser=Cyberfox', 'Mozilla/5.0 (Windows NT 6.3; Win64; x64; rv:30.0) Gecko/20100101 Firefox/30.0 Cyberfox/30.0')
# ('Cyberfox', 'https://udger.com/resources/ua-list/browser-detail?browser=Cyberfox', 'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:33.0) Gecko/20100101 Firefox/33.0 Cyberfox/33.0.2')
# ('Deepnet Explorer', 'https://udger.com/resources/ua-list/browser-detail?browser=Deepnet%20Explorer', 'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; Deepnet Explorer 1.5.0; .NET CLR 1.0.3705)')
# ('Degdegan', 'https://udger.com/resources/ua-list/browser-detail?browser=Degdegan', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Degdegan/72.4.206 Chrome/66.4.3359.206 Safari/537.36')
# ('Demeter', 'https://udger.com/resources/ua-list/browser-detail?browser=Demeter', 'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_5_6; en-us) AppleWebKit/525.27.1 (KHTML, like Gecko) Demeter/1.0.9 Safari/125')
# ('DeskBrowse', 'https://udger.com/resources/ua-list/browser-detail?browser=DeskBrowse', 'Mozilla/5.0 (Macintosh; U; PPC Mac OS X; pl-pl) AppleWebKit/312.8 (KHTML, like Gecko, Safari) DeskBrowse/1.0')
# ('Dillo', 'https://udger.com/resources/ua-list/browser-detail?browser=Dillo', 'Dillo/0.8.5')
# ('Dillo', 'https://udger.com/resources/ua-list/browser-detail?browser=Dillo', 'Dillo/2.0')
# ('Dillo', 'https://udger.com/resources/ua-list/browser-detail?browser=Dillo', 'Dillo/0.7.3')
# ('Dillo', 'https://udger.com/resources/ua-list/browser-detail?browser=Dillo', 'Dillo/2.2')
# ('Dillo', 'https://udger.com/resources/ua-list/browser-detail?browser=Dillo', 'Dillo/3.0.2')
# ('Dillo', 'https://udger.com/resources/ua-list/browser-detail?browser=Dillo', 'Mozilla/4.0 (compatible; Dillo 3.0)')
# ('DocZilla', 'https://udger.com/resources/ua-list/browser-detail?browser=DocZilla', 'DocZilla/2.7 (Windows; U; Windows NT 5.1; en-US; rv:2.7.0) Gecko/20050706 CiTEC Information')
# ('DocZilla', 'https://udger.com/resources/ua-list/browser-detail?browser=DocZilla', 'DocZilla/1.0 (Windows; U; WinNT4.0; en-US; rv:1.0.0) Gecko/20020804')
# ('Dooble', 'https://udger.com/resources/ua-list/browser-detail?browser=Dooble', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; cs-CZ) AppleWebKit/527+ (KHTML, like Gecko, Safari/419.3)  Dooble')
# ('Dooble', 'https://udger.com/resources/ua-list/browser-detail?browser=Dooble', 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/534.34 (KHTML, like Gecko) Dooble/1.41 Safari/534.34')
# ('DPlus', 'https://udger.com/resources/ua-list/browser-detail?browser=DPlus', 'Mozilla/4.0 (compatible; DPlus 0.5)')
# ('Edbrowse', 'https://udger.com/resources/ua-list/browser-detail?browser=Edbrowse', 'edbrowse/2.2.10')
# ('Edbrowse', 'https://udger.com/resources/ua-list/browser-detail?browser=Edbrowse', 'edbrowse/3.1.2-1')
# ('Edbrowse', 'https://udger.com/resources/ua-list/browser-detail?browser=Edbrowse', 'edbrowse/1.5.17-2')
# ('Electron App', 'https://udger.com/resources/ua-list/browser-detail?browser=Electron%20App', 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Rocket.Chat+/2.9.0 Chrome/58.0.3029.110 Electron/1.7.6 Safari/537.36')
# ('Electron App', 'https://udger.com/resources/ua-list/browser-detail?browser=Electron%20App', 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) review-tool/2.3.5 Chrome/56.0.2924.87 Electron/1.6.10 Safari/537.36')
# ('Element Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Element%20Browser', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US) AppleWebKit/533+ (KHTML, like Gecko) Element Browser 5.0')
# ('Element Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Element%20Browser', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; cs-CZ) AppleWebKit/533+ (KHTML, like Gecko) Element Browser 6.0')
# ('Elements Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Elements%20Browser', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.16.3282.140 Elements Browser/1.1.16 Safari/537.36')
# ('Elinks', 'https://udger.com/resources/ua-list/browser-detail?browser=Elinks', 'ELinks/0.13.GIT (textmode; Linux 2.6.22-2-686 i686; 148x68-3)')
# ('Elinks', 'https://udger.com/resources/ua-list/browser-detail?browser=Elinks', 'ELinks/0.9.3 (textmode; Linux 2.6.11 i686; 79x24)')
# ('Enigma browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Enigma%20browser', 'Enigma Browser')
# ('Epic', 'https://udger.com/resources/ua-list/browser-detail?browser=Epic', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.2.10) Gecko/20101026 Epic/1.2 Firefox/3.6.10')
# ('Epic', 'https://udger.com/resources/ua-list/browser-detail?browser=Epic', 'Mozilla/5.0 (Windows; U; Windows NT 5.2; en-US; rv:1.9.2.7) Gecko/20100723 Epic/1.1 Firefox/3.6.7')
# ('Epic', 'https://udger.com/resources/ua-list/browser-detail?browser=Epic', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.2.6) Gecko/20100702 Epic/1.0 Firefox/3.6.6')
# ('Espial TV Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Espial%20TV%20Browser', 'Mozilla/4.0 (compatible; MSIE 5.23; Macintosh; PPC) Escape 5.1.1')
# ('Espial TV Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Espial%20TV%20Browser', 'Mozilla/4.0 (compatible; MSIE 5.23; Macintosh; PPC) Escape 5.1.8')
# ('Espial TV Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Espial%20TV%20Browser', 'Mozilla/4.61 [en] (Win32; Escape 4.8; U)')
# ('Espial TV Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Espial%20TV%20Browser', 'Mozilla/5.0 (DTV) AppleWebKit/531.2+ (KHTML, like Gecko) Espial/6.0.4')
# ('Espial TV Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Espial%20TV%20Browser', 'Mozilla/5.0 (DTV) AppleWebKit/531.2+ (KHTML, like Gecko) Espial/6.1.5 AQUOSBrowser/2.0 (US01DTV;V;0001;0001)')
# ('Facebook App for desktop', 'https://udger.com/resources/ua-list/browser-detail?browser=Facebook%20App%20for%20desktop', 'Mozilla/5.0 (Windows NT 10.0.17134.165; osmeta 10.3.3308) AppleWebKit/602.1.1 (KHTML, like Gecko) Version/9.0 Safari/602.1.1 osmeta/10.3.3308 Build/3308 [FBAN/FBW;FBAV/140.0.0.232.179;FBBV/83145113;FBDV/WindowsDevice;FBMD/Inspiron 3541;FBSN/Windows;FBSV/10.0.17134.228;FBSS/1;FBCR/;FBID/desktop;FBLC/en_US;FBOP/45;FBRV/0]')
# ('Falkon', 'https://udger.com/resources/ua-list/browser-detail?browser=Falkon', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Falkon/3.0.1 Chrome/61.0.3163.140 Safari/537.36')
# ('Firebird (old name for Firefox)', 'https://udger.com/resources/ua-list/browser-detail?browser=Firebird%20(old%20name%20for%20Firefox)', 'Mozilla/5.0 (Windows; U; Win98; en-US; rv:1.5) Gecko/20031007 Firebird/0.7')
# ('Firebird (old name for Firefox)', 'https://udger.com/resources/ua-list/browser-detail?browser=Firebird%20(old%20name%20for%20Firefox)', 'Mozilla/5.0 (Windows; U; Win95; en-US; rv:1.5) Gecko/20031007 Firebird/0.7')
# ('Firefox', 'https://udger.com/resources/ua-list/browser-detail?browser=Firefox', 'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.5; en-US; rv:1.9.1b3) Gecko/20090305 Firefox/3.1b3 GTB5')
# ('Firefox', 'https://udger.com/resources/ua-list/browser-detail?browser=Firefox', 'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.5; ko; rv:1.9.1b2) Gecko/20081201 Firefox/3.1b2')
# ('Firefox', 'https://udger.com/resources/ua-list/browser-detail?browser=Firefox', 'Mozilla/5.0 (X11; U; SunOS sun4u; en-US; rv:1.9b5) Gecko/2008032620 Firefox/3.0b5')
# ('Firefox', 'https://udger.com/resources/ua-list/browser-detail?browser=Firefox', 'Mozilla/5.0 (X11; U; Linux x86_64; en-US; rv:1.8.1.12) Gecko/20080214 Firefox/2.0.0.12')
# ('Firefox', 'https://udger.com/resources/ua-list/browser-detail?browser=Firefox', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; cs; rv:1.9.0.8) Gecko/2009032609 Firefox/3.0.8')
# ('Firefox', 'https://udger.com/resources/ua-list/browser-detail?browser=Firefox', 'Mozilla/5.0 (X11; U; OpenBSD i386; en-US; rv:1.8.0.5) Gecko/20060819 Firefox/1.5.0.5')
# ('Firefox', 'https://udger.com/resources/ua-list/browser-detail?browser=Firefox', 'Mozilla/5.0 (Windows; U; Windows NT 5.0; es-ES; rv:1.8.0.3) Gecko/20060426 Firefox/1.5.0.3')
# ('Firefox', 'https://udger.com/resources/ua-list/browser-detail?browser=Firefox', 'Mozilla/5.0 (Windows; U; WinNT4.0; en-US; rv:1.7.9) Gecko/20050711 Firefox/1.0.5')
# ('Firefox', 'https://udger.com/resources/ua-list/browser-detail?browser=Firefox', 'Mozilla/5.0 (Windows; Windows NT 6.1; rv:2.0b2) Gecko/20100720 Firefox/4.0b2')
# ('Firefox', 'https://udger.com/resources/ua-list/browser-detail?browser=Firefox', 'Mozilla/5.0 (X11; Linux x86_64; rv:2.0b4) Gecko/20100818 Firefox/4.0b4')
# ('Firefox', 'https://udger.com/resources/ua-list/browser-detail?browser=Firefox', 'Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.2) Gecko/20100308 Ubuntu/10.04 (lucid) Firefox/3.6 GTB7.1')
# ('Firefox', 'https://udger.com/resources/ua-list/browser-detail?browser=Firefox', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:2.0b7) Gecko/20101111 Firefox/4.0b7')
# ('Firefox', 'https://udger.com/resources/ua-list/browser-detail?browser=Firefox', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:2.0b8pre) Gecko/20101114 Firefox/4.0b8pre')
# ('Firefox', 'https://udger.com/resources/ua-list/browser-detail?browser=Firefox', 'Mozilla/5.0 (X11; Linux x86_64; rv:2.0b9pre) Gecko/20110111 Firefox/4.0b9pre')
# ...
# ('Opera', 'https://udger.com/resources/ua-list/browser-detail?browser=Opera', 'Opera/9.80 (Windows NT 5.1; U; cs) Presto/2.2.15 Version/10.00')
# ('Opera', 'https://udger.com/resources/ua-list/browser-detail?browser=Opera', 'Opera/9.80 (Windows NT 6.1; U; sv) Presto/2.7.62 Version/11.01')
# ('Opera', 'https://udger.com/resources/ua-list/browser-detail?browser=Opera', 'Opera/9.80 (Windows NT 6.1; U; en-GB) Presto/2.7.62 Version/11.00')
# ('Opera', 'https://udger.com/resources/ua-list/browser-detail?browser=Opera', 'Opera/9.80 (Windows NT 6.1; U; zh-tw) Presto/2.7.62 Version/11.01')
# ('Opera', 'https://udger.com/resources/ua-list/browser-detail?browser=Opera', 'Opera/9.80 (Windows NT 6.0; U; en) Presto/2.8.99 Version/11.10')
# ('Opera', 'https://udger.com/resources/ua-list/browser-detail?browser=Opera', 'Opera/9.80 (X11; Linux i686; U; ru) Presto/2.8.131 Version/11.11')
# ('Opera', 'https://udger.com/resources/ua-list/browser-detail?browser=Opera', 'Opera/9.80 (Windows NT 5.1) Presto/2.12.388 Version/12.14')
# ('Opera', 'https://udger.com/resources/ua-list/browser-detail?browser=Opera', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.12 Safari/537.36 OPR/14.0.1116.4')
# ('Opera', 'https://udger.com/resources/ua-list/browser-detail?browser=Opera', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1500.29 Safari/537.36 OPR/15.0.1147.24 (Edition Next)')
# ('Opera', 'https://udger.com/resources/ua-list/browser-detail?browser=Opera', 'Opera/9.80 (Linux armv6l ; U; CE-HTML/1.0 NETTV/3.0.1;; en) Presto/2.6.33 Version/10.60')
# ('Opera', 'https://udger.com/resources/ua-list/browser-detail?browser=Opera', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/33.0.1750.154 Safari/537.36 OPR/20.0.1387.91')
# ('Opera', 'https://udger.com/resources/ua-list/browser-detail?browser=Opera', 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Oupeng/10.2.1.86910 Safari/534.30')
# ('Opera', 'https://udger.com/resources/ua-list/browser-detail?browser=Opera', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36 OPR/26.0.1656.60')
# ('Opera', 'https://udger.com/resources/ua-list/browser-detail?browser=Opera', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2376.0 Safari/537.36 OPR/31.0.1857.0')
# ('Opera', 'https://udger.com/resources/ua-list/browser-detail?browser=Opera', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.85 Safari/537.36 OPR/32.0.1948.25')
# ('Opera GX', 'https://udger.com/resources/ua-list/browser-detail?browser=Opera%20GX', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36 OPR/60.0.3255.50747 OPRGX/60.0.3255.50747')
# ('Opera Neon', 'https://udger.com/resources/ua-list/browser-detail?browser=Opera%20Neon', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.21 Safari/537.36 MMS/1.0.2459.0')
# ('Orange browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Orange%20browser', 'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; GTB7.4; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; JuziBrowser)')
# ('Orange browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Orange%20browser', 'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/6.0; JuziBrowser)')
# ('Orange browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Orange%20browser', 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0; JuziBrowser) like Gecko')
# ('Orca', 'https://udger.com/resources/ua-list/browser-detail?browser=Orca', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.6) Gecko/2009022300 Firefox/3.0.6 Orca/1.1 build 1')
# ('Orca', 'https://udger.com/resources/ua-list/browser-detail?browser=Orca', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009030821 Firefox/3.0.7 Orca/1.1 build 2')
# ('Orca', 'https://udger.com/resources/ua-list/browser-detail?browser=Orca', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091222 Firefox/3.5.6 Orca/1.2 build 6')
# ('Oregano', 'https://udger.com/resources/ua-list/browser-detail?browser=Oregano', 'Mozilla/1.10 [en] (Compatible; RISC OS 3.70; Oregano 1.10)')
# ('Otter', 'https://udger.com/resources/ua-list/browser-detail?browser=Otter', 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/538.1 (KHTML, like Gecko) Otter/0.1.01 Safari/538.1')
# ('Otter', 'https://udger.com/resources/ua-list/browser-detail?browser=Otter', 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/538.1 (KHTML, like Gecko) Otter/0.0.01 Safari/538.1')
# ('Otter', 'https://udger.com/resources/ua-list/browser-detail?browser=Otter', 'Mozilla/5.0 (X11; Linux i686) AppleWebKit/538.1 (KHTML, like Gecko) Otter/0.2.01-dev Safari/538.1')
# ('Otter', 'https://udger.com/resources/ua-list/browser-detail?browser=Otter', 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/538.1 (KHTML, like Gecko) Otter/0.3.01-dev Safari/538.1')
# ('Otter', 'https://udger.com/resources/ua-list/browser-detail?browser=Otter', 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/538.1 (KHTML, like Gecko) Otter/0.4.01 Safari/538.1')
# ('Otter', 'https://udger.com/resources/ua-list/browser-detail?browser=Otter', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/538.1 (KHTML, like Gecko) Otter/0.9.03 beta 3 Safari/538.1')
# ('Otter', 'https://udger.com/resources/ua-list/browser-detail?browser=Otter', 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/538.1 (KHTML, like Gecko) Otter/0.9.05')
# ('OWB (Odyssey Web Browser)', 'https://udger.com/resources/ua-list/browser-detail?browser=OWB%20(Odyssey%20Web%20Browser)', 'Mozilla/5.0 (Macintosh; PowerPC MorphOS 3.7; Odyssey Web Browser; rv:1.24) AppleWebKit/538.10 (KHTML, like Gecko) OWB/1.24 Safari/538.10')
# ('OWB (Origyn Web Browser)', 'https://udger.com/resources/ua-list/browser-detail?browser=OWB%20(Origyn%20Web%20Browser)', 'Mozilla/5.0 (compatible; Origyn Web Browser; AmigaOS 4.0; U; en) AppleWebKit/531.0+ (KHTML, like Gecko, Safari/531.0+)')
# ('OWB (Origyn Web Browser)', 'https://udger.com/resources/ua-list/browser-detail?browser=OWB%20(Origyn%20Web%20Browser)', 'Mozilla/5.0 (compatible; Origyn Web Browser; MorphOS; PPC; U) AppleWebKit/528.5+ (KHTML, like Gecko, Safari/528.5+)')
# ('OWB (Origyn Web Browser)', 'https://udger.com/resources/ua-list/browser-detail?browser=OWB%20(Origyn%20Web%20Browser)', 'Mozilla/5.0 (compatible; Origyn Web Browser; AmigaOS 4.1; ppc; U; en) AppleWebKit/530.0+ (KHTML, like Gecko, Safari/530.0+)')
# ('Pale Moon', 'https://udger.com/resources/ua-list/browser-detail?browser=Pale%20Moon', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.2) Gecko/20100206 Palemoon/3.6.0.5')
# ('Pale Moon', 'https://udger.com/resources/ua-list/browser-detail?browser=Pale%20Moon', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.2.3) Gecko/20100403 Firefox/3.6.3 (Palemoon/3.6.3)')
# ('Pale Moon', 'https://udger.com/resources/ua-list/browser-detail?browser=Pale%20Moon', 'Mozilla/5.0 (Windows NT 6.2; WOW64; rv:19.0) Gecko/20130308 Firefox/19.0 PaleMoon/19.0.2')
# ('Pale Moon', 'https://udger.com/resources/ua-list/browser-detail?browser=Pale%20Moon', 'Mozilla/5.0 (Windows NT 5.1; rv:24.0) Gecko/20140208 Firefox/24.0 PaleMoon/24.3.2')
# ('Pale Moon', 'https://udger.com/resources/ua-list/browser-detail?browser=Pale%20Moon', 'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:19.0) Gecko/20130223 Firefox/19.0 PaleMoon/19.0.1-x64')
# ('Pale Moon', 'https://udger.com/resources/ua-list/browser-detail?browser=Pale%20Moon', 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:24.7) Gecko/20140802 Firefox/24.7 PaleMoon/24.7.1')
# ('Pale Moon', 'https://udger.com/resources/ua-list/browser-detail?browser=Pale%20Moon', 'Mozilla/5.0 (X11; Linux x86_64; rv:45.9) Gecko/20100101 Goanna/3.0 Firefox/45.9 PaleMoon/27.0.3')
# ('Patriott', 'https://udger.com/resources/ua-list/browser-detail?browser=Patriott', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; cs-CZ) AppleWebKit/533.3 (KHTML, like Gecko) Patriott::Browser/1.0.0 Safari/533.3')
# ('Patriott', 'https://udger.com/resources/ua-list/browser-detail?browser=Patriott', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; fr-FR) AppleWebKit/533.3 (KHTML, like Gecko) Patriott::Browser/0.0.1 alpha test Safari/533.3')
# ('Perk', 'https://udger.com/resources/ua-list/browser-detail?browser=Perk', 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.22 (KHTML, like Gecko) Chrome/25.0.1364.97 Safari/537.22 Perk/3.6.0.0')
# ('Perk', 'https://udger.com/resources/ua-list/browser-detail?browser=Perk', 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.22 (KHTML, like Gecko) Chrome/25.0.1364.97 Safari/537.22 Perk/3.3.0.0')
# ('Perk', 'https://udger.com/resources/ua-list/browser-detail?browser=Perk', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_5) AppleWebKit/537.22 (KHTML, like Gecko) Chrome/25.0.1364.152 Safari/537.22 Perk/3.6.0.0')
# ('Phaseout', 'https://udger.com/resources/ua-list/browser-detail?browser=Phaseout', 'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; PhaseOut-www.phaseout.net)')
# ('Phoenix (old name for Firefox)', 'https://udger.com/resources/ua-list/browser-detail?browser=Phoenix%20(old%20name%20for%20Firefox)', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.4a) Gecko/20030411 Phoenix/0.5')
# ('Phoenix (old name for Firefox)', 'https://udger.com/resources/ua-list/browser-detail?browser=Phoenix%20(old%20name%20for%20Firefox)', 'Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.2b) Gecko/20021029 Phoenix/0.4')
# ('PirateBrowser', 'https://udger.com/resources/ua-list/browser-detail?browser=PirateBrowser', 'PB1.0b Mozilla/5.0 (Windows NT 6.3; WOW64; rv:37.0) Gecko/20100101 Firefox/37.0')
# ('Polarity', 'https://udger.com/resources/ua-list/browser-detail?browser=Polarity', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.2.12) Gecko/20101026 Villanova/1.9.2.12 Polarity/3.0.0 Firefox/4.0')
# ('PS4 Web browser', 'https://udger.com/resources/ua-list/browser-detail?browser=PS4%20Web%20browser', 'Mozilla/5.0 (PlayStation 4 1.000) AppleWebKit/536.26 (KHTML, like Gecko)')
# ('PS4 Web browser', 'https://udger.com/resources/ua-list/browser-detail?browser=PS4%20Web%20browser', 'Mozilla/5.0 (PlayStation 4 1.52) AppleWebKit/536.26 (KHTML, like Gecko)')
# ('Puffin', 'https://udger.com/resources/ua-list/browser-detail?browser=Puffin', 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.117 Safari/537.36 Puffin/7.2.2.927WD')
# ('PureBrowser', 'https://udger.com/resources/ua-list/browser-detail?browser=PureBrowser', 'Mozilla/5.0 (X11; Linux x86_64; rv:45.0) Gecko/20100101 PureBrowser/46.2.0')
# ('PureBrowser', 'https://udger.com/resources/ua-list/browser-detail?browser=PureBrowser', 'Mozilla/5.0 (X11; Linux x86_64; rv:60.0) Gecko/20100101 Firefox/60.0 PureBrowser/60.9.0')
# ('Qiyu Swordfish Browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Qiyu%20Swordfish%20Browser', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.63 Safari/537.36 Qiyu/2.1.1.0')
# ('QQbrowser', 'https://udger.com/resources/ua-list/browser-detail?browser=QQbrowser', 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.80 Safari/537.36 QQBrowser/9.3.6874.400')
# ('QQbrowser', 'https://udger.com/resources/ua-list/browser-detail?browser=QQbrowser', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36 QQBrowser/3.8.3858.400')
# ('QtWeb', 'https://udger.com/resources/ua-list/browser-detail?browser=QtWeb', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; cs-CZ) AppleWebKit/527+ (KHTML, like Gecko)  QtWeb Internet Browser/2.5 http://www.QtWeb.net')
# ('QtWeb', 'https://udger.com/resources/ua-list/browser-detail?browser=QtWeb', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/527+ (KHTML, like Gecko) QtWeb Internet Browser/1.2 http://www.QtWeb.net')
# ('QtWeb', 'https://udger.com/resources/ua-list/browser-detail?browser=QtWeb', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/527+ (KHTML, like Gecko) QtWeb Internet Browser/1.7 http://www.QtWeb.net')
# ('QtWeb', 'https://udger.com/resources/ua-list/browser-detail?browser=QtWeb', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; cs-CZ) AppleWebKit/532.4 (KHTML, like Gecko)  QtWeb Internet Browser/3.3 http://www.QtWeb.net')
# ('QtWeb', 'https://udger.com/resources/ua-list/browser-detail?browser=QtWeb', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; pt-BR) AppleWebKit/533.3 (KHTML, like Gecko)  QtWeb Internet Browser/3.7 http://www.QtWeb.net')
# ('QupZilla', 'https://udger.com/resources/ua-list/browser-detail?browser=QupZilla', 'Mozilla/5.0 (Windows; U; Windows NT 6.1; cs-CZ) AppleWebKit/533.3 (KHTML, like Gecko) QupZilla/1.1.5 Safari/533.3')
# ('QupZilla', 'https://udger.com/resources/ua-list/browser-detail?browser=QupZilla', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; cs-CZ) AppleWebKit/533.3 (KHTML, like Gecko) QupZilla/1.1.5 Safari/533.3')
# ('QupZilla', 'https://udger.com/resources/ua-list/browser-detail?browser=QupZilla', 'Mozilla/5.0 (Macintosh; U; PPC Mac OS X; en-US) AppleWebKit/533.3 (KHTML, like Gecko) QupZilla/1.1.5 Safari/533.3')
# ('QupZilla', 'https://udger.com/resources/ua-list/browser-detail?browser=QupZilla', 'Mozilla/5.0 (Windows; U; Windows NT 5.1; es-ES) AppleWebKit/533.3 (KHTML, like Gecko) QupZilla/1.1.0 Safari/533.3')
# ('QupZilla', 'https://udger.com/resources/ua-list/browser-detail?browser=QupZilla', 'Mozilla/5.0 (X11; U; Linux i686; pl-PL) AppleWebKit/533.3 (KHTML, like Gecko) QupZilla/1.0.0-rc1 Safari/533.3')
# ('QupZilla', 'https://udger.com/resources/ua-list/browser-detail?browser=QupZilla', 'Mozilla/5.0 (Unknown; UNIX BSD/SYSV system) AppleWebKit/538.1 (KHTML, like Gecko) QupZilla/1.7.0 Safari/538.1')
# ('QupZilla', 'https://udger.com/resources/ua-list/browser-detail?browser=QupZilla', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) QupZilla/2.0.2 Chrome/45.0.2454.101 Safari/537.36')
# ('qutebrowser', 'https://udger.com/resources/ua-list/browser-detail?browser=qutebrowser', 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/538.1 (KHTML, like Gecko) qutebrowser/0.2.1 Safari/538.1')
# ('qutebrowser', 'https://udger.com/resources/ua-list/browser-detail?browser=qutebrowser', 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/538.1 (KHTML, like Gecko) qutebrowser/0.9.1 Safari/538.1')
# ('Rambler browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Rambler%20browser', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/33.0.1750.117 Safari/537.36 Nichrome/self/33')
# ('Rambler browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Rambler%20browser', 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/33.0.1750.117 Safari/537.36 Nichrome/self/33')
# ('Rambler browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Rambler%20browser', 'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/33.0.1750.117 Safari/537.36 Nichrome/self/33')
# ('Rambler browser', 'https://udger.com/resources/ua-list/browser-detail?browser=Rambler%20browser', 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/30.0.1599.101 Safari/537.36 Nichrome/self/30')
# ('Rekonq', 'https://udger.com/resources/ua-list/browser-detail?browser=Rekonq', 'Mozilla/5.0 (X11; U; Linux; cs-CZ) AppleWebKit/527+ (KHTML, like Gecko, Safari/419.3)  rekonq')
# ('Rekonq', 'https://udger.com/resources/ua-list/browser-detail?browser=Rekonq', 'Mozilla/5.0 (X11; U; Linux i686; pl-PL) AppleWebKit/533.3 (KHTML, like Gecko) rekonq Safari/533.3')
# ('Rekonq', 'https://udger.com/resources/ua-list/browser-detail?browser=Rekonq', 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.21 (KHTML, like Gecko) rekonq/2.2.1 Safari/537.21')

# %%
# Create lists of information, create a dataframe and save it
names = []
urls = []
ua = []
for triple in TRIPLE:
    names.append(triple[0])
    urls.append(triple[1])
    ua.append(triple[2])
    
columns = {"browser_name": names, "browser_url": urls, "user-agent": ua}
df = pd.DataFrame(columns)
df.to_csv("User_agent_table.csv", sep="µ", index=False)
